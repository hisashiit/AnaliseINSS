# %%
import numpy as np
from matplotlib import pyplot as plt
Contri_mensal = 951.63
Tempo_apo_Homem = 40 #anos
Tempo_apo_Mulher = 35 #anos
RendimentoAno = 1+9/100 # rendimento por ano
RendimentoMensal = RendimentoAno**(1/12)
t = np.arange(Tempo_apo_Homem * 12) 
Montante = Contri_mensal
Y = [0]*Tempo_apo_Homem*12
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y[i] = Contri_mensal
        continue
    Montante = Montante*(RendimentoMensal) + Contri_mensal
    Y[i] = Montante

plt.plot(t, Y, color="#1437E4", linestyle='-',label='Homem montante 40 anos')

plt.xlabel('Tempo em Meses')
plt.ylabel('Montante em Reais')
plt.title('Montante em relação ao tempo em meses decorridos')

plt.legend()

plt.tight_layout()

plt.show()

# %%
Y[Tempo_apo_Homem*12-1]
# Out:
# 4015154.4667333816

# %%
import numpy as np
from matplotlib import pyplot as plt
InflacaoAnual = 1+5/100 #inflacao a cada ano
InflacaoMensal = InflacaoAnual**(1/12)
Contri_mensal = 951.63
Tempo_apo_Homem = 40 #anos
Tempo_apo_Mulher = 35 #anos
RendimentoAno = 1+9/100 # rendimento por ano
RendimentoMensal = RendimentoAno**(1/12)
t = np.arange(Tempo_apo_Homem * 12) 
Montante = Contri_mensal
Y = [0]*Tempo_apo_Homem*12
Y_infla = [0]*Tempo_apo_Homem*12
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y[i] = Contri_mensal
        continue
    Montante = Montante*(RendimentoMensal) + Contri_mensal
    Y[i] = Montante
Y_infla_ant = 0
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y_infla_ant = InflacaoMensal
        Y_infla[i] = Y_infla_ant
        continue
    Y_infla_ant = Y_infla_ant*InflacaoMensal
    Y_infla[i] = Y_infla_ant

plt.plot(t, Y_infla, color="#E81714", linestyle='-',label='Inflação')

plt.xlabel('Tempo em Meses')
plt.ylabel('Inflação')
plt.title('Inflação em relação ao tempo decorrido')

plt.legend()

plt.tight_layout()

plt.show()

# %%
InflacaoMensal
# Out:
# 1.0040741237836484

# %%
Y[40*12-1]
# Out:
# 4015154.4667333816

# %%
1.0040741237836484**12
# Out:
# 1.0500000000000007

# %%
import numpy as np
from matplotlib import pyplot as plt
InflacaoAnual = 1+5/100 #inflacao a cada ano
InflacaoMensal = InflacaoAnual**(1/12)
Contri_mensal = 951.63
Tempo_apo_Homem = 40 #anos
Tempo_apo_Mulher = 35 #anos
RendimentoAno = 1+9/100 # rendimento por ano
RendimentoMensal = RendimentoAno**(1/12)
t = np.arange(Tempo_apo_Homem * 12) 
Montante = Contri_mensal
Y = [0]*Tempo_apo_Homem*12
Y_infla = [0]*Tempo_apo_Homem*12
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y[i] = Contri_mensal
        continue
    Montante = Montante*(RendimentoMensal) + Contri_mensal
    Y[i] = Montante
Y_infla_ant = 0
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y_infla_ant = InflacaoMensal
        Y_infla[i] = (Y_infla_ant-1)*100
        continue
    Y_infla_ant = Y_infla_ant*InflacaoMensal
    Y_infla[i] = (Y_infla_ant-1)*100

plt.plot(t, Y_infla, color="#E81714", linestyle='-',label='Inflação')

plt.xlabel('Tempo em Meses')
plt.ylabel('Inflação [%]')
plt.title('Inflação em relação ao tempo decorrido')

plt.legend()

plt.tight_layout()

plt.show()

# %%
Y_infla[Tempo_apo_Homem*12-1]
# Out:
# 603.9988712124817

# %%
import numpy as np
from matplotlib import pyplot as plt
InflacaoAnual = 1+5/100 #inflacao a cada ano
InflacaoMensal = InflacaoAnual**(1/12)
Contri_mensal = 951.63
Tempo_apo_Homem = 40 #anos
Tempo_apo_Mulher = 35 #anos
RendimentoAno = 1+9/100 # rendimento por ano
RendimentoMensal = RendimentoAno**(1/12)
t = np.arange(Tempo_apo_Homem * 12) 
Montante = Contri_mensal
Y = [0]*Tempo_apo_Homem*12
RazaoY_inflaEY = [0]*Tempo_apo_Homem*12
Y_infla = [0]*Tempo_apo_Homem*12
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y[i] = Contri_mensal
        continue
    Montante = Montante*(RendimentoMensal) + Contri_mensal
    Y[i] = Montante
Y_infla_ant = 0
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y_infla_ant = InflacaoMensal
        Y_infla[i] = Y_infla_ant
        continue
    Y_infla_ant = Y_infla_ant*InflacaoMensal
    Y_infla[i] = Y_infla_ant
    RazaoY_inflaEY[i] = Y[i]/Y_infla[i]

plt.plot(t, RazaoY_inflaEY, color="#23D366", linestyle='-',label='Montante com inflação')
plt.plot(t, Y, color="#2518D6", linestyle='-',label='Montante sem inflação')

plt.xlabel('Tempo em Meses')
plt.ylabel('Montante [reais]')
plt.title('Montantes')

plt.legend()

plt.tight_layout()

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
InflacaoAnual = 1+5/100 #inflacao a cada ano
InflacaoMensal = InflacaoAnual**(1/12)
Contri_mensal = 951.63
Tempo_apo_Homem = 40 #anos
Tempo_apo_Mulher = 35 #anos
RendimentoAno = 1+9/100 # rendimento por ano
RendimentoMensal = RendimentoAno**(1/12)
t = np.arange(Tempo_apo_Homem * 12) 
Montante = Contri_mensal
Y = [0]*Tempo_apo_Homem*12
RazaoY_inflaEY = [0]*Tempo_apo_Homem*12
Y_infla = [0]*Tempo_apo_Homem*12
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y[i] = Contri_mensal
        continue
    Montante = Montante*(RendimentoMensal) + Contri_mensal
    Y[i] = Montante
Y_infla_ant = 0
for i in range(Tempo_apo_Homem*12):
    if i == 0:
        Y_infla_ant = InflacaoMensal
        Y_infla[i] = Y_infla_ant
        continue
    Y_infla_ant = Y_infla_ant*InflacaoMensal
    Y_infla[i] = Y_infla_ant
    RazaoY_inflaEY[i] = Y[i]/Y_infla[i]

plt.plot(t, RazaoY_inflaEY, color="#23D366", linestyle='-',label='Montante com inflação')

plt.xlabel('Tempo em Meses')
plt.ylabel('Montante [reais]')
plt.title('Montantes')

plt.legend()

plt.tight_layout()

plt.show()

# %%
print(RazaoY_inflaEY[Tempo_apo_Homem*12-1])
# Out:
# 570335.3557681377

# %%
Total_Montante_Real_Inicio = RazaoY_inflaEY[Tempo_apo_Homem*12-1]
TempoVida = 15 #anos
TetoINSS = 8157.41
Montante_Aposent = [0]*96
TempoTotal = np.arange(96)
for i in range(96):
    if i == 0:
        Montante_Aposentado = Total_Montante_Real_Inicio - TetoINSS
        Montante_Aposent[i] = Montante_Aposentado 
        continue
    Montante_Aposentado = Montante_Aposentado - TetoINSS
    Montante_Aposentado = Montante_Aposentado*RendimentoMensal
    Montante_Aposent[i] = Montante_Aposentado
    if Montante_Aposent[i] < 0:
        print(f"O aposentado perde todo o dinheiro no mes {i+1}")
        break

plt.plot(TempoTotal, Montante_Aposent, color="#23D366", linestyle='-',label='Montante aposentado')

plt.xlabel('Tempo em Meses')
plt.ylabel('Montante [reais]')
plt.title('Montante do aposentado gastando 8157 reais por mes')

plt.legend()

plt.tight_layout()

plt.show()
# Out:
# O aposentado perde todo o dinheiro no mes 96
